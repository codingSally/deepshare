# %%
# 了解一下dask

# %%
import pandas as pd
import pandas_profiling as ppf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dbac838f8a28> in <module>
#       1 import pandas as pd
# ----> 2 import pandas_profiling as ppf
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
train_data = pd.read_csv("data/second_round_training_data.csv")
test_data = pd.read_csv("data/second_round_testing_data.csv")

# %%
train_data.head()
# Out:
#    Parameter1  Parameter2  Parameter3   Parameter4  Parameter5  Parameter6  \
# 0    0.167898  104.443982    2.772825     0.146548    0.000421    0.000612
# 1  252.483066    0.343232    0.066873     0.002495    0.000909    0.002397
# 2    4.124654    0.170534    0.383800     0.000004    0.000909    0.001972
# 3  294.656750    6.153711    0.014716  4284.326273    0.000909    0.002397
# 4    0.026284    0.166810    7.587398     0.002202    0.000909    0.002397
#
#     Parameter7  Parameter8  Parameter9  Parameter10  ...  Attribute2  \
# 0  2286.523413    0.035407    0.593081     1.010385  ...    2.597820
# 1  2286.523413    0.035407    0.593081     1.010385  ...    0.004243
# 2  2286.523413    0.035407    0.593081     1.010385  ...    0.951186
# 3  2286.523413    0.035407    0.593081     1.010385  ...    0.000122
# 4  2286.523413    0.035407    0.593081     1.010385  ...    0.827308
#
#    Attribute3  Attribute4  Attribute5    Attribute6  Attribute7  Attribute8  \
# ...

# %%
# 一、 查看数据具体内容

1. # 查看数据是否有确实
train_data.isnull().sum()
# Out:
# Parameter1       0
# Parameter2       0
# Parameter3       0
# Parameter4       0
# Parameter5       0
# Parameter6       0
# Parameter7       0
# Parameter8       0
# Parameter9       0
# Parameter10      0
# Attribute1       0
# Attribute2       0
# Attribute3       0
# Attribute4       0
# Attribute5       0
# Attribute6       0
# Attribute7       0
# Attribute8       0
# Attribute9       0
# Attribute10      0
# Quality_label    0
# dtype: int64

# %%
# 2. 查看某一列数据是否有缺失
train_data.Parameter1.isnull().sum() # 先判断是否有空，然后再统计个数
# Out:
# 0

# %%
# 3. 数据类型查看 -- 明白数据类型转换
train_data.dtypes
# Out:
# Parameter1       float64
# Parameter2       float64
# Parameter3       float64
# Parameter4       float64
# Parameter5       float64
# Parameter6       float64
# Parameter7       float64
# Parameter8       float64
# Parameter9       float64
# Parameter10      float64
# Attribute1       float64
# Attribute2       float64
# Attribute3       float64
# Attribute4       float64
# Attribute5       float64
# Attribute6       float64
# Attribute7       float64
# Attribute8       float64
# Attribute9       float64
# Attribute10      float64
# Quality_label     object
# dtype: object

# %%
# 4. 数据大小查看
train_data.info() # 查看具体的信息内容
len(train_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12934 entries, 0 to 12933
# Data columns (total 21 columns):
# Parameter1       12934 non-null float64
# Parameter2       12934 non-null float64
# Parameter3       12934 non-null float64
# Parameter4       12934 non-null float64
# Parameter5       12934 non-null float64
# Parameter6       12934 non-null float64
# Parameter7       12934 non-null float64
# Parameter8       12934 non-null float64
# Parameter9       12934 non-null float64
# Parameter10      12934 non-null float64
# Attribute1       12934 non-null float64
# Attribute2       12934 non-null float64
# Attribute3       12934 non-null float64
# Attribute4       12934 non-null float64
# Attribute5       12934 non-null float64
# Attribute6       12934 non-null float64
# Attribute7       12934 non-null float64
# Attribute8       12934 non-null float64
# Attribute9       12934 non-null float64
# Attribute10      12934 non-null float64
# Quality_label    12934 non-null object
# ...

# %%
# 5. 自动化EDA工具 -- 主要看警告 EDA[数据探索]
ppf.ProfileReport(train_data)  
# 看偏度 -- 偏度书需要去偏操作
# 相关性 -- 看有没有冗余特征 【相关性非相关，则没有冗余特征，做特征工程就比较好做，只需要去偏度】

# %%
test_data.describe() # 对数据整体性的统计
# Out:
#            Group    Parameter1   Parameter10    Parameter2    Parameter3  \
# count  6000.0000  6.000000e+03   6000.000000   6000.000000  6.000000e+03
# mean     59.5000  8.265658e+03     43.034446    126.223368  2.994860e+03
# std      34.6427  2.487136e+05    211.335566   1738.767879  8.078260e+04
# min       0.0000  8.420000e-08      0.001024      0.000021  4.040000e-08
# 25%      29.7500  7.400040e-02      0.101478      0.117208  7.070190e-02
# 50%      59.5000  9.988808e-01      1.403055      0.997680  9.449328e-01
# 75%      89.2500  1.195355e+01     13.969790      9.050826  1.495138e+01
# max     119.0000  1.396008e+07  13789.079120  92366.836240  5.027128e+06
#
#          Parameter4   Parameter5    Parameter6    Parameter7    Parameter8  \
# count  6.000000e+03  6000.000000  6.000000e+03   6000.000000   6000.000000
# mean   1.212453e+05     6.937771  6.559966e+00    184.351056     43.946117
# std    5.416637e+06     9.921864  8.560064e+00   1333.057844   1279.488170
# ...
